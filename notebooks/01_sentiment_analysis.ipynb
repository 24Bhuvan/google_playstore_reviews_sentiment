# %%
# notebooks/01_sentiment_analysis.ipynb (core cells)

import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv("../data/processed/sentiment_labeled.csv")

# quick checks
df.head()
df["sentiment"].value_counts(normalize=True) * 100

# distribution plot
df["sentiment"].value_counts().plot(kind="bar", title="Sentiment Distribution")
plt.tight_layout()
plt.show()

# text length sanity check
df["content"].str.len().describe()
# Out:
# count    11561.000000
# mean       154.758152
# std        149.218914
# min          1.000000
# 25%         46.000000
# 50%        106.000000
# 75%        219.000000
# max       3956.000000
# Name: content, dtype: float64
